# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read('../preprocessing/data/import/Tcell.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 459755 × 34849
#     obs: 'sample_id', 'study_id', 'donor_id', 'barcode', 'tissue', 'chem', 'sort', 'has_tcr', 'n_counts', 'log10_counts', 'n_genes', 'pct_counts_mt', 'pct_counts_hb', 'pct_counts_ig', 'scr_doublet', 'scr_doublet_score', 'UMAP1', 'UMAP2', 'MDE1', 'MDE2', 'leiden_0.6', 'subset', 'pheno', 'CD3pos', 'CD4pos', 'CD8pos', 'clone_id', 'Naive', 'Cytotoxicity', 'Nonviral'
#     var: 'gene', 'n_counts', 'n_cells_by_counts', 'mt', 'hb', 'ig'
#     uns: 'leiden', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_mde', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs['pheno'].value_counts()/adata.n_obs * 100
# Out:
# CD4.Tn           27.609488
# CD4.Tcm          11.574208
# CD8.TemActive     8.107579
# CD8.Tn            7.636894
# CD8.TemTerm       6.816022
# CD8.TEMRA         5.668019
# CD4.CTL           4.865635
# CD4.Treg          4.694674
# CD8.Tem.IL7R      4.436928
# CD4.Th17          4.034540
# CD4.Tem           3.423345
# MAIT_gdT          3.042925
# Teff.IFIT2        2.124392
# CD8.Trm           1.934074
# CD8.Tcm           1.730269
# CD8.Tem.KLRG1     1.016846
# Prolif.           0.602930
# ISG.ISG15         0.411306
# CD8.Tex           0.269926
# Name: pheno, dtype: float64

# %%
tex_markers = ['CD69','HLA-DRA','HLA-DRB1','ICOS','PDCD1','TIGIT',
               'LAG3','CTLA4','HAVCR2','CXCL13','ENTPD1','LAYN','TOX','TOX2']

# %%
sc.pl.dotplot(adata[(adata.obs['subset']=='CD8') & (adata.obs['pheno']!='CD8.Tex')], 
              tex_markers, 
              'pheno', 
              use_raw=False, swap_axes=False, standard_scale='var', dendrogram=False)
# Out:
# /Users/kaneucl/miniconda3/envs/Increate22/lib/python3.8/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)
